# %%
import pandas as pd 

total_dataset_v1 = pd.read_csv('./total_cleaned_v1.csv', sep=',')

print(total_dataset_v1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Respondentnummer  Gender Zip-code  \
# 0             0           0.0          210153.0     1.0  2516 VN
# 1             1           1.0          212120.0     1.0  3079 HK
# 2             2           2.0          219179.0     1.0  2526 HR
# 3             3           3.0          219172.0     0.0  2526 HR
# 4             4           4.0          201163.0     0.0      NaN
# ..          ...           ...               ...     ...      ...
# 547         547         547.0          219304.0     1.0      NaN
# 548         548         548.0          207117.0     1.0  2313 AB
# 549         549         549.0          209121.0     0.0  2571 VD
# 550         550         550.0          209146.0     0.0  2571 VD
# 551         551           NaN               NaN     NaN      NaN
#
#     Geboortedatum  Age on testday (t0)  Leeftijd (op testdag)  \
# 0      21.08.2016               4.0903                 4.0903
# ...

# %%
total_dataset_v1.drop('Age on testday (t0).1', axis=1, inplace=True)

# %%
print(total_dataset_v1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Respondentnummer  Gender Zip-code  \
# 0             0           0.0          210153.0     1.0  2516 VN
# 1             1           1.0          212120.0     1.0  3079 HK
# 2             2           2.0          219179.0     1.0  2526 HR
# 3             3           3.0          219172.0     0.0  2526 HR
# 4             4           4.0          201163.0     0.0      NaN
# ..          ...           ...               ...     ...      ...
# 547         547         547.0          219304.0     1.0      NaN
# 548         548         548.0          207117.0     1.0  2313 AB
# 549         549         549.0          209121.0     0.0  2571 VD
# 550         550         550.0          209146.0     0.0  2571 VD
# 551         551           NaN               NaN     NaN      NaN
#
#     Geboortedatum  Age on testday (t0)  Leeftijd (op testdag)  \
# 0      21.08.2016               4.0903                 4.0903
# ...

# %%
total_dataset_v1.drop('Unnamed: 0', axis=1, inplace=True)

# %%
print(total_dataset_v1)
# Out:
#      Unnamed: 0.1  Respondentnummer  Gender Zip-code Geboortedatum  \
# 0             0.0          210153.0     1.0  2516 VN    21.08.2016
# 1             1.0          212120.0     1.0  3079 HK    12.01.2016
# 2             2.0          219179.0     1.0  2526 HR    19.01.2016
# 3             3.0          219172.0     0.0  2526 HR    17.01.2016
# 4             4.0          201163.0     0.0      NaN    17.12.2015
# ..            ...               ...     ...      ...           ...
# 547         547.0          219304.0     1.0      NaN    30.01.2013
# 548         548.0          207117.0     1.0  2313 AB    07.05.2013
# 549         549.0          209121.0     0.0  2571 VD    10.07.2013
# 550         550.0          209146.0     0.0  2571 VD    07.02.2013
# 551           NaN               NaN     NaN      NaN           NaN
#
#      Age on testday (t0)  Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)  \
# 0                 4.0903                 4.0903                        28.10
# ...

# %%
total_dataset_v1.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
print(total_dataset_v1)
# Out:
#      Respondentnummer  Gender Zip-code Geboortedatum  Age on testday (t0)  \
# 0            210153.0     1.0  2516 VN    21.08.2016               4.0903
# 1            212120.0     1.0  3079 HK    12.01.2016               4.1424
# 2            219179.0     1.0  2526 HR    19.01.2016               4.1424
# 3            219172.0     0.0  2526 HR    17.01.2016               4.1478
# 4            201163.0     0.0      NaN    17.12.2015               4.1780
# ..                ...     ...      ...           ...                  ...
# 547          219304.0     1.0      NaN    30.01.2013               7.1102
# 548          207117.0     1.0  2313 AB    07.05.2013               7.1704
# 549          209121.0     0.0  2571 VD    10.07.2013               7.2197
# 550          209146.0     0.0  2571 VD    07.02.2013               7.6386
# 551               NaN     NaN      NaN           NaN                  NaN
#
#      Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)          MQ  \
# ...

# %%
total_dataset_v1.drop('Opmerkingen 2.1', axis=1, inplace=True)

# %%
total_dataset_v1.drop('Opmerkingen2', axis=1, inplace=True)

# %%
print(total_dataset_v1)
# Out:
#      Respondentnummer  Gender Zip-code Geboortedatum  Age on testday (t0)  \
# 0            210153.0     1.0  2516 VN    21.08.2016               4.0903
# 1            212120.0     1.0  3079 HK    12.01.2016               4.1424
# 2            219179.0     1.0  2526 HR    19.01.2016               4.1424
# 3            219172.0     0.0  2526 HR    17.01.2016               4.1478
# 4            201163.0     0.0      NaN    17.12.2015               4.1780
# ..                ...     ...      ...           ...                  ...
# 547          219304.0     1.0      NaN    30.01.2013               7.1102
# 548          207117.0     1.0  2313 AB    07.05.2013               7.1704
# 549          209121.0     0.0  2571 VD    10.07.2013               7.2197
# 550          209146.0     0.0  2571 VD    07.02.2013               7.6386
# 551               NaN     NaN      NaN           NaN                  NaN
#
#      Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)          MQ  \
# ...

# %%
total_dataset_v1.to_csv(r'./total_cleaned_v2.csv')
