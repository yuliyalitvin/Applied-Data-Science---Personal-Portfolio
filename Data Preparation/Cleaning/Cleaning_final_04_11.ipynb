# %%
import pandas as pd 

df_test = pd.read_csv('./Test_middleStep.csv', sep=',')

print(df_test)
# Out:
#      Unnamed: 0  Respondentnummer  Gender Geboortedatum  Age on testday (t0)  \
# 0             1            310103       1    17.02.2017               3.0300
# 1             2            303110       1    01.02.2016               4.0300
# 2             3            302121       1    19.11.2015               4.0600
# 3             4            302128       0    15.11.2015               4.0700
# 4             5            309122       1    28.09.2016               4.0800
# ..          ...               ...     ...           ...                  ...
# 959         961            220268       0    01.09.2013               7.0856
# 960         962            219304       1    30.01.2013               7.1102
# 961         963            207117       1    07.05.2013               7.1704
# 962         964            209121       0    10.07.2013               7.2197
# 963         965            209146       0    07.02.2013               7.6386
#
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
print(df_test["Testdatum 2"])
print(df_test["Testdatum 2"][7])
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7      04/07/2021
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15     03/29/2021
# 16     06/17/2021
# 17     06/17/2021
# 18            NaN
# 19            NaN
# 20     03/31/2021
# 21            NaN
# 22     06/17/2021
# 23            NaN
# 24     06/17/2021
# 25     06/17/2021
# 26            NaN
# 27            NaN
# 28            NaN
# 29     06/17/2021
# 30     06/17/2021
# 31     04/07/2021
# 32            NaN
# 33     03/29/2021
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42     06/16/2021
# 43     06/16/2021
# 44     03/31/2021
# 45            NaN
# 46     03/31/2021
# 47            NaN
# 48            NaN
# 49            NaN
# ...

# %%
df_test = df_test.drop([49, 54])

# %%
df_test['Age on testday (t1)'].isnull().values.sum()
# Out:
# 16

# %%
print(df_test['Age on testday (t1)'])
# Out:
# 0                  5.82
# 1                  5.12
# 2                  5.59
# 3                   5.6
# 4                  4.66
# 5                  5.18
# 6      4.62696783025325
# 7                  5.64
# 8                   4.7
# 9                   4.7
# 10                 5.65
# 11                 5.21
# 12                 4.71
# 13                 4.72
# 14     5.21013004791239
# 15             5.413699
# 16             5.419178
# 17                 6.21
# 18                 5.55
# 19     5.28678986995209
# 20                 4.76
# 21             5.452055
# 22                 4.77
# 23     5.45927446954141
# 24     5.47022587268994
# 25                  4.8
# 26             5.482192
# 27                 5.33
# 28             5.493151
# 29     5.48939082819986
# 30     4.76933607118412
# 31                 4.83
# 32     5.32511978097194
# 33                 5.37
# 34                 5.38
# 35                 5.69
# 36                 5.69
# 37                 5.65
# ...

# %%
df_test = df_test.drop([89, 285, 397, 486, 490, 501, 639, 677, 724, 756, 788, 812, 899, 962])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)
print(df_test)
# Out:
#      Unnamed: 0  Respondentnummer  Gender Geboortedatum  Age on testday (t0)  \
# 0             1            310103       1    17.02.2017               3.0300
# 1             2            303110       1    01.02.2016               4.0300
# 2             3            302121       1    19.11.2015               4.0600
# 3             4            302128       0    15.11.2015               4.0700
# 4             5            309122       1    28.09.2016               4.0800
# 5             6            303131       0    10.01.2016               4.0900
# 6             7            210153       1    21.08.2016               4.0903
# 7             8            302129       1    01.11.2015               4.1100
# 8             9            309137       1    15.09.2016               4.1100
# 9            10            309141       0    15.09.2016               4.1100
# 10           11            302120       0    27.10.2015               4.1200
# ...

# %%
print(df_test['Testdatum 2'][15])
print(df_test['Geboortedatum'][15])
# Out:
# 17.06.2021
# 19.01.2016

# %%
# df_test['Age on testday (t1)'][17] = abs((df_test['Testdatum 2'][17] - df_test['Geboortedatum'][17]).days)
# print(df_test['Age on testday (t1)'][17])

from datetime import datetime

date_1 = str(df_test['Testdatum 2'][15])
date_2 = str(df_test['Geboortedatum'][15])
start = datetime.strptime(date_1, "%d.%m.%Y")
end =   datetime.strptime(date_2, "%d.%m.%Y")
diff = start.date() - end.date()

print('Difference between dates in days:')
print(diff.days)

df_test['Age on testday (t1)'][15] = 1976/365

print(df_test['Age on testday (t1)'][15])
# Out:
# Difference between dates in days:
# 1976
# 5.413698630136986
# <ipython-input-30-99b9d9d356bd>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Age on testday (t1)'][15] = 1976/365

# %%
print(df_test['Age on testday (t1)'][330])
# Out:
# 5.73032169746749

# %%
df_test['Age on testday (t1)'][16] = 1978/365
df_test['Age on testday (t1)'][21] = 1990/365
df_test['Age on testday (t1)'][26] = 2001/365
df_test['Age on testday (t1)'][28] = 2005/365
df_test['Age on testday (t1)'][40] = 2023/365
df_test['Age on testday (t1)'][102] = 2129/365
df_test['Age on testday (t1)'][195] = 2214/365
df_test['Age on testday (t1)'][331] = 2333/365
# Out:
# <ipython-input-35-f6d96b72a9bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Age on testday (t1)'][16] = 1978/365
# <ipython-input-35-f6d96b72a9bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Age on testday (t1)'][21] = 1990/365
# <ipython-input-35-f6d96b72a9bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Age on testday (t1)'][26] = 2001/365
# ...

# %%
df_test['Age on testday (t1)'].isnull().values.sum()
# Out:
# 16

# %%
print(df_test['Age on testday (t1)'])
# Out:
# 0                  5.82
# 1                  5.12
# 2                  5.59
# 3                   5.6
# 4                  4.66
# 5                  5.18
# 6      4.62696783025325
# 7                  5.64
# 8                   4.7
# 9                   4.7
# 10                 5.65
# 11                 5.21
# 12                 4.71
# 13                 4.72
# 14     5.21013004791239
# 15             5.413699
# 16             5.419178
# 17                 6.21
# 18                 5.55
# 19     5.28678986995209
# 20                 4.76
# 21             5.452055
# 22                 4.77
# 23     5.45927446954141
# 24     5.47022587268994
# 25                  4.8
# 26             5.482192
# 27                 5.33
# 28             5.493151
# 29     5.48939082819986
# 30     4.76933607118412
# 31                 4.83
# 32     5.32511978097194
# 33                 5.37
# 34                 5.38
# 35                 5.69
# 36                 5.69
# 37                 5.65
# ...

# %%
print(df_test.shape)
# Out:
# (948, 135)

# %%
print(df_test['Age on testday (t1)'])
# Out:
# 0                  5.82
# 1                  5.12
# 2                  5.59
# 3                   5.6
# 4                  4.66
# 5                  5.18
# 6      4.62696783025325
# 7                  5.64
# 8                   4.7
# 9                   4.7
# 10                 5.65
# 11                 5.21
# 12                 4.71
# 13                 4.72
# 14     5.21013004791239
# 15             5.413699
# 16             5.419178
# 17                 6.21
# 18                 5.55
# 19     5.28678986995209
# 20                 4.76
# 21             5.452055
# 22                 4.77
# 23     5.45927446954141
# 24     5.47022587268994
# 25                  4.8
# 26             5.482192
# 27                 5.33
# 28             5.493151
# 29     5.48939082819986
# 30     4.76933607118412
# 31                 4.83
# 32     5.32511978097194
# 33                 5.37
# 34                 5.38
# 35                 5.69
# 36                 5.69
# 37                 5.65
# ...

# %%
df_test = df_test.drop([47, 52, 87, 283, 395, 484, 488, 499, 637, 675, 722, 754, 786, 810, 853, 897, 960])

# %%
df_test['Age on testday (t1)'].isnull().values.sum()
# Out:
# 0

# %%
df_test.to_csv(r'./Cleaned_merged_dataset.csv')
