# %%
import pandas as pd 

total_dataset_v3 = pd.read_csv('./total_cleaned_v2.csv', sep=',')

print(total_dataset_v3)
# Out:
#      Unnamed: 0  Respondentnummer  Gender Zip-code Geboortedatum  \
# 0             0          210153.0     1.0  2516 VN    21.08.2016
# 1             1          212120.0     1.0  3079 HK    12.01.2016
# 2             2          219179.0     1.0  2526 HR    19.01.2016
# 3             3          219172.0     0.0  2526 HR    17.01.2016
# 4             4          201163.0     0.0      NaN    17.12.2015
# ..          ...               ...     ...      ...           ...
# 547         547          219304.0     1.0      NaN    30.01.2013
# 548         548          207117.0     1.0  2313 AB    07.05.2013
# 549         549          209121.0     0.0  2571 VD    10.07.2013
# 550         550          209146.0     0.0  2571 VD    07.02.2013
# 551         551          202175.0     1.0  3082 VW    28.03.2014
#
#      Age on testday (t0)  Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)  \
# 0                 4.0903                 4.0903                     28.10000
# ...

# %%
print(total_dataset_v3)
# Out:
#      Unnamed: 0  Respondentnummer  Gender Zip-code Geboortedatum  \
# 0             0          210153.0     1.0  2516 VN    21.08.2016
# 1             1          212120.0     1.0  3079 HK    12.01.2016
# 2             2          219179.0     1.0  2526 HR    19.01.2016
# 3             3          219172.0     0.0  2526 HR    17.01.2016
# 4             4          201163.0     0.0      NaN    17.12.2015
# ..          ...               ...     ...      ...           ...
# 547         547          219304.0     1.0      NaN    30.01.2013
# 548         548          207117.0     1.0  2313 AB    07.05.2013
# 549         549          209121.0     0.0  2571 VD    10.07.2013
# 550         550          209146.0     0.0  2571 VD    07.02.2013
# 551         551          202175.0     1.0  3082 VW    28.03.2014
#
#      Age on testday (t0)  Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)  \
# 0                 4.0903                 4.0903                     28.10000
# ...

# %%
total_dataset_v3.drop('Unnamed: 0', axis=1, inplace=True)

# %%
print(total_dataset_v3)
# Out:
#      Respondentnummer  Gender Zip-code Geboortedatum  Age on testday (t0)  \
# 0            210153.0     1.0  2516 VN    21.08.2016               4.0903
# 1            212120.0     1.0  3079 HK    12.01.2016               4.1424
# 2            219179.0     1.0  2526 HR    19.01.2016               4.1424
# 3            219172.0     0.0  2526 HR    17.01.2016               4.1478
# 4            201163.0     0.0      NaN    17.12.2015               4.1780
# ..                ...     ...      ...           ...                  ...
# 547          219304.0     1.0      NaN    30.01.2013               7.1102
# 548          207117.0     1.0  2313 AB    07.05.2013               7.1704
# 549          209121.0     0.0  2571 VD    10.07.2013               7.2197
# 550          209146.0     0.0  2571 VD    07.02.2013               7.6386
# 551          202175.0     1.0  3082 VW    28.03.2014                  NaN
#
#      Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)          MQ  \
# ...

# %%
total_dataset_v3.drop('Leeftijd (op testdag)', axis=1, inplace=True)

# %%
print(total_dataset_v3)
# Out:
#      Respondentnummer  Gender Zip-code Geboortedatum  Age on testday (t0)  \
# 0            210153.0     1.0  2516 VN    21.08.2016               4.0903
# 1            212120.0     1.0  3079 HK    12.01.2016               4.1424
# 2            219179.0     1.0  2526 HR    19.01.2016               4.1424
# 3            219172.0     0.0  2526 HR    17.01.2016               4.1478
# 4            201163.0     0.0      NaN    17.12.2015               4.1780
# ..                ...     ...      ...           ...                  ...
# 547          219304.0     1.0      NaN    30.01.2013               7.1102
# 548          207117.0     1.0  2313 AB    07.05.2013               7.1704
# 549          209121.0     0.0  2571 VD    10.07.2013               7.2197
# 550          209146.0     0.0  2571 VD    07.02.2013               7.6386
# 551          202175.0     1.0  3082 VW    28.03.2014                  NaN
#
#      AST (tijd afgerond op 0.1s)          MQ  Lengte (afgerond op 0.1 cm)  \
# ...

# %%
total_dataset_v3.to_csv(r'./total_cleaned_v3.csv')
