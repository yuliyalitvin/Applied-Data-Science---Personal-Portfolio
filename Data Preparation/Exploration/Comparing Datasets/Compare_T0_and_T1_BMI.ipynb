# %%
# Compare Datasets T0 and T1 --> BMI

import pandas as pd
import numpy as np

t0_data = pd.read_csv('T0_With questionaire.csv', sep=';')

t1_data = pd.read_csv('HHS_T1_20_10_21.csv', error_bad_lines=False, sep=';')

t0_data['BMI T1'] = t1_data['BMI T1']
t0_data['BMI_difference'] = t1_data['BMI T1'].astype(float) - t0_data['BMI'].astype(float)

count_pos_n = 0
count_neg_n = 0 

for num in t0_data['BMI_difference']:
    if num >= 0:
        count_pos_n += 1
    else:
        count_neg_n += 1

print("Count of positive differences: ", count_pos_n) 
print("Count of negative differences: ", count_neg_n)

print(t0_data)
# Out:
# Count of positive differences:  355
# Count of negative differences:  1354
#       Respondentnummer  Gender  IC  Zip-code Geboortedatum  \
# 0               307117     1.0    1      NaN           NaN
# 1               307173     0.0    1      NaN           NaN
# 2               307174     0.0    1      NaN           NaN
# 3               310103     1.0    1      NaN   17.Feb.2017
# 4               110240     0.0    1      NaN   22-Oct-2016
# ...                ...     ...  ...      ...           ...
# 1704            302130     1.0    1      NaN           NaN
# 1705            305134     0.0    1      NaN           NaN
# 1706            305138     0.0    1      NaN           NaN
# 1707            305162     0.0    1      NaN           NaN
# 1708            306108     0.0    1  2546 SK           NaN
#
#       Leeftijd (op testdag)  AST (tijd afgerond op 0.1s)   MQ Opmerkingen  \
# 0                      0.00                         26.7  0.0         NaN
# 1                      0.00                         23.0  0.0         NaN
# 2                      0.00                         19.8  0.0         NaN
# 3                      3.03                         34.3  0.0         NaN
# 4                      3.33                         31.0  0.0         NaN
# ...                     ...                          ...  ...         ...
# 1704                    NaN                         40.7  NaN         NaN
# 1705                    NaN                         31.2  NaN         NaN
# 1706                    NaN                         30.4  NaN         NaN
# 1707                    NaN                         19.0  NaN         NaN
# 1708                    NaN                         25.1  NaN         NaN
#
#       Lengte (afgerond op 0.1 cm)  ...  belonen_wanneer_rustig  \
# 0                           115.3  ...                     NaN
# 1                           114.0  ...                     NaN
# 2                           117.0  ...                     NaN
# 3                           114.8  ...                     2.0
# 4                           122.8  ...                     NaN
# ...                           ...  ...                     ...
# 1704                        115.2  ...                     3.0
# 1705                        118.2  ...                     NaN
# 1706                        109.2  ...                     NaN
# 1707                        115.9  ...                     NaN
# 1708                        110.0  ...                     NaN
#
#       buitenspeel_materiaal_beschikbaar  tv_bezighouden  \
# 0                                   NaN             NaN
# 1                                   NaN             NaN
# 2                                   NaN             NaN
# 3                                   5.0             2.0
# 4                                   NaN             NaN
# ...                                 ...             ...
# 1704                                5.0             2.0
# 1705                                NaN             NaN
# 1706                                NaN             NaN
# 1707                                NaN             NaN
# 1708                                NaN             NaN
#
#       niet_buiten_verkeersveiligheid  niet_buiten_criminaliteit  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                1.0                        1.0
# 4                                NaN                        NaN
# ...                              ...                        ...
# 1704                             1.0                        1.0
# 1705                             NaN                        NaN
# 1706                             NaN                        NaN
# 1707                             NaN                        NaN
# 1708                             NaN                        NaN
#
#       toestaan_langetijd_schermen  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                           999.0
# 4                             NaN
# ...                           ...
# 1704                          2.0
# 1705                          NaN
# 1706                          NaN
# 1707                          NaN
# 1708                          NaN
#
#                                 toelichting_vragenlijst  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Toezicht-> buitenspelen. Dochter is 5 jaar oud ;)
# 4                                                   NaN
# ...                                                 ...
# 1704                                                NaN
# 1705                                                NaN
# 1706                                                NaN
# 1707                                                NaN
# 1708                                                NaN
#
#                            tips_opmerkingen_vragenlijst     BMI T1  \
# 0                                                   NaN  21.153833
# 1                                                   NaN  14.083793
# 2                                                   NaN  17.601807
# 3     Soms zijn het bewuste keuzes mbv time-auto bij...  15.535626
# 4                                                   NaN  14.873654
# ...                                                 ...        ...
# 1704                                                NaN        NaN
# 1705                                                NaN        NaN
# 1706                                                NaN        NaN
# 1707                                                NaN        NaN
# 1708                                                NaN        NaN
#
#       BMI_difference
# 0           7.083833
# 1          -1.076207
# 2           2.701807
# 3          -1.614374
# 4           1.083654
# ...              ...
# 1704             NaN
# 1705             NaN
# 1706             NaN
# 1707             NaN
# 1708             NaN
#
# [1709 rows x 158 columns]

# %%
t0_data.set_index('Respondentnummer', inplace=True)
t1_data.set_index('Respondentnummer', inplace=True)

print(t0_data['BMI_difference'])

print(np.mean(t0_data['BMI_difference']))
# Out:
# Respondentnummer
# 307117    7.083833
# 307173   -1.076207
# 307174    2.701807
# 310103   -1.614374
# 110240    1.083654
#             ...
# 302130         NaN
# 305134         NaN
# 305138         NaN
# 305162         NaN
# 306108         NaN
# Name: BMI_difference, Length: 1709, dtype: float64
# 0.8485034497621734

# %%
import matplotlib.pyplot as plt

plt.hist(t0_data['BMI_difference'])
plt.show()
